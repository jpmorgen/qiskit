# %%
from qiskit import __version__

print(__version__)
# Out:
# 2.3.0

# %%
from qiskit.quantum_info import Statevector, Operator
from numpy import sqrt

# %%
plus = Statevector.from_label("+")
minus_i = Statevector.from_label("l")
phi = plus.tensor(minus_i)
display(phi.draw("latex"))
# Out:
# $$\frac{1}{2} |00\rangle- \frac{i}{2} |01\rangle+\frac{1}{2} |10\rangle- \frac{i}{2} |11\rangle$$

# %%
display(plus.draw("latex"))
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle$$

# %%
display(minus_i.draw("latex"))
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle- \frac{\sqrt{2} i}{2} |1\rangle$$

# %%
minus = Statevector.from_label("-")
display(minus.draw("latex"))
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle- \frac{\sqrt{2}}{2} |1\rangle$$

# %%
w = Statevector([0, 1, 1, 0, 1, 0, 0, 0] / sqrt(3))
display(w.draw("latex"))

result, state = w.measure([0])
print(f"Measured: {result}\nState after measurement:")
display(state.draw("latex"))

result, state = w.measure([0, 1])
print(f"Measured: {result}\nState after measurement:")
display(state.draw("latex"))
# Out:
# $$\frac{\sqrt{3}}{3} |001\rangle+\frac{\sqrt{3}}{3} |010\rangle+\frac{\sqrt{3}}{3} |100\rangle$$
# Measured: 1
# State after measurement:
# $$ |001\rangle$$
# Measured: 10
# State after measurement:
# $$ |010\rangle$$

# %%
from qiskit.quantum_info import Statevector
from numpy import sqrt

u = Statevector([1 / sqrt(2), 1 / sqrt(2)])
v = Statevector([(1 + 2.0j) / 3, -2 / 3])
w = Statevector([1 / 3, 2 / 3])

# %%
display(u.draw("text"))
display(u.draw("latex"))
print(u.draw("latex_source"))
# Out:
# [0.70710678+0.j,0.70710678+0.j]
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle$$
# \frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle

# %%
display(v.draw("latex"))
# Out:
# $$(\frac{1}{3} + \frac{2 i}{3}) |0\rangle- \frac{2}{3} |1\rangle$$

# %%
display(v.draw("text"))
# Out:
# [ 0.33333333+0.66666667j,-0.66666667+0.j        ]

# %%
ws = Statevector([0, 1, 1, 0] / sqrt(3))
display(ws.draw("latex"))
# Out:
# $$\frac{\sqrt{3}}{3} |01\rangle+\frac{\sqrt{3}}{3} |10\rangle$$

# %%
# I was struggling here how to figure out how the Statevector input array translated into the output expression.  Figured it out below
wm = Statevector([0, 1, 1, 0, 1, 0] / sqrt(3))
display(wm.draw("latex"))
# Out:
# $$\begin{align}
#
#
# \begin{bmatrix}
# 0 & \frac{\sqrt{3}}{3} & \frac{\sqrt{3}}{3} & 0 & \frac{\sqrt{3}}{3} & 0  \\
#  \end{bmatrix}
# \\
# \text{dims=(6,)}
# \end{align}$$

# %%
w = Statevector([0, 1, 1, 0, 1, 0, 0, 0] / sqrt(3))
display(w.draw("latex"))
# Out:
# $$\frac{\sqrt{3}}{3} |001\rangle+\frac{\sqrt{3}}{3} |010\rangle+\frac{\sqrt{3}}{3} |100\rangle$$

# %%
wl = Statevector([0, 1, 1, 0, 1, 0, 0, 0] / sqrt(3))
display(wl.draw("latex"))
# Out:
# $$\frac{\sqrt{3}}{3} |001\rangle+\frac{\sqrt{3}}{3} |010\rangle+\frac{\sqrt{3}}{3} |100\rangle$$

# %%
ghz = Statevector([0, 0, 0, 0, 1, 1, 1, 1]/sqrt(2))
display(ghz.draw("latex"))
# Out:
# $$\frac{\sqrt{2}}{2} |100\rangle+\frac{\sqrt{2}}{2} |101\rangle+\frac{\sqrt{2}}{2} |110\rangle+\frac{\sqrt{2}}{2} |111\rangle$$

# %%
ghz = Statevector([0, 0, 0, 0, 0, 0, 0, 1]/sqrt(2))
display(ghz.draw("latex"))
# Out:
# $$\frac{\sqrt{2}}{2} |111\rangle$$

# %%
ghz = display(ghz.draw("latex"))
display(ghz.draw("latex"))
# Out:
# $$\frac{\sqrt{2}}{2} |110\rangle+\frac{\sqrt{2}}{2} |111\rangle$$

# %%
ghz = Statevector([0, 0, 0, 0, 0, 0, 1, 0]/sqrt(2))
display(ghz.draw("latex"))
# Out:
# $$\frac{\sqrt{2}}{2} |110\rangle$$

# %%
print('demonstrate that Statevector works a little funny for 3+ bit systems.')
print('  3 bits have 2**3=8 combinations, so there are 8 elements in the vector that get set')
print(' correpsonding to the permutations and combinations of the 3 bits')
ghz = Statevector([1, 0, 0, 0, 0, 0, 0, 1]/sqrt(2))
display(ghz.draw("latex"))
# Out:
# demonstrate that Statevector works a little funny for 3+ bit systems.
#   3 bits have 2**3=8 combinations, so there are 8 elements in the vector that get set
#  correpsonding to the permutations and combinations of the 3 bits
# $$\frac{\sqrt{2}}{2} |000\rangle+\frac{\sqrt{2}}{2} |111\rangle$$

# %%
two_bit = Statevector([1, 0, 1, 0]/sqrt(2))
display(two_bit.draw("latex"))
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |10\rangle$$

# %%
# Of course, we can use the tensor product to put things together too:
a = Statevector([1,0]/sqrt(2))
aa = a.tensor(a)
display(aa.draw("latex"))
# Out:
# $$\frac{1}{2} |00\rangle$$

# %%
w = Statevector([0, 1, 1, 0, 1, 0, 0, 0] / sqrt(3))
display(w.draw("latex"))

result, state = w.measure([0])
print(f"Measured: {result}\nState after measurement:")
display(state.draw("latex"))

result, state = w.measure([0, 1])
print(f"Measured: {result}\nState after measurement:")
display(state.draw("latex"))
# Out:
# $$\frac{\sqrt{3}}{3} |001\rangle+\frac{\sqrt{3}}{3} |010\rangle+\frac{\sqrt{3}}{3} |100\rangle$$
# Measured: 0
# State after measurement:
# $$\frac{\sqrt{2}}{2} |010\rangle+\frac{\sqrt{2}}{2} |100\rangle$$
# Measured: 00
# State after measurement:
# $$ |100\rangle$$
